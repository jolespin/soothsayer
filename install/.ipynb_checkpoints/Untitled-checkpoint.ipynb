# %%
import soothsayer as sy
import ensemble_networkx as enx
import soothsayer_utils as syu
import numpy as np
from scipy import stats

# Load in data
X,y = syu.get_iris_data(["X", "y"])

# %%
df_dism = 1 - X.corr()
ahc = sy.Agglomerative(df_dism)
ahc.cluster()
ahc.plot(style="ggplot")
# Out:
#  ..cutHeight not given, setting it to 1.59  ===>  99% of the (truncated) height range in dendro.
#  cutHeight set too low: no merges below the cut.
# (<Figure size 2100x500 with 2 Axes>,
#  [<Axes: ylabel='Distance'>, <Axes: ylabel='cluster'>])

# %%
import seaborn
